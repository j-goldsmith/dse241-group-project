# %%
import pandas as pd
import numpy as np

# %%
df =  pd.read_csv('H-1B_Disclosure_Data_FY17.csv')
# Out:
# C:\Anaconda2\envs\py36\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (15,16,17,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.drop('Unnamed: 0',inplace=True,axis=1)

# %%
df.columns
# Out:
# Index(['CASE_NUMBER', 'CASE_STATUS', 'CASE_SUBMITTED', 'DECISION_DATE',
#        'VISA_CLASS', 'EMPLOYMENT_START_DATE', 'EMPLOYMENT_END_DATE',
#        'EMPLOYER_NAME', 'EMPLOYER_BUSINESS_DBA', 'EMPLOYER_ADDRESS',
#        'EMPLOYER_CITY', 'EMPLOYER_STATE', 'EMPLOYER_POSTAL_CODE',
#        'EMPLOYER_COUNTRY', 'EMPLOYER_PROVINCE', 'EMPLOYER_PHONE',
#        'EMPLOYER_PHONE_EXT', 'AGENT_REPRESENTING_EMPLOYER',
#        'AGENT_ATTORNEY_NAME', 'AGENT_ATTORNEY_CITY', 'AGENT_ATTORNEY_STATE',
#        'JOB_TITLE', 'SOC_CODE', 'SOC_NAME', 'NAICS_CODE', 'TOTAL_WORKERS',
#        'NEW_EMPLOYMENT', 'CONTINUED_EMPLOYMENT', 'CHANGE_PREVIOUS_EMPLOYMENT',
#        'NEW_CONCURRENT_EMPLOYMENT', 'CHANGE_EMPLOYER', 'AMENDED_PETITION',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'PW_UNIT_OF_PAY',
#        'PW_WAGE_LEVEL', 'PW_SOURCE', 'PW_SOURCE_YEAR', 'PW_SOURCE_OTHER',
#        'WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_TO', 'WAGE_UNIT_OF_PAY',
# ...

# %%
df.groupby('CASE_STATUS').count()
# Out:
#                      CASE_NUMBER  CASE_SUBMITTED  DECISION_DATE  VISA_CLASS  \
# CASE_STATUS
# CERTIFIED                 545694          545694         545694      545694
# CERTIFIED-WITHDRAWN        49704           49704          49704       49704
# DENIED                      8480            8480           8480        8480
# WITHDRAWN                  20772           20772          20772       20772
#
#                      EMPLOYMENT_START_DATE  EMPLOYMENT_END_DATE  \
# CASE_STATUS
# CERTIFIED                           545674               545673
# CERTIFIED-WITHDRAWN                  49704                49704
# DENIED                                8474                 8474
# WITHDRAWN                            20769                20769
#
#                      EMPLOYER_NAME  EMPLOYER_BUSINESS_DBA  EMPLOYER_ADDRESS  \
# CASE_STATUS
# CERTIFIED                   545662                  36497            545693
# ...

# %%
df=df[df['VISA_CLASS']=='H-1B']

# %%
df.columns
# Out:
# Index(['CASE_NUMBER', 'CASE_STATUS', 'CASE_SUBMITTED', 'DECISION_DATE',
#        'VISA_CLASS', 'EMPLOYMENT_START_DATE', 'EMPLOYMENT_END_DATE',
#        'EMPLOYER_NAME', 'EMPLOYER_BUSINESS_DBA', 'EMPLOYER_ADDRESS',
#        'EMPLOYER_CITY', 'EMPLOYER_STATE', 'EMPLOYER_POSTAL_CODE',
#        'EMPLOYER_COUNTRY', 'EMPLOYER_PROVINCE', 'EMPLOYER_PHONE',
#        'EMPLOYER_PHONE_EXT', 'AGENT_REPRESENTING_EMPLOYER',
#        'AGENT_ATTORNEY_NAME', 'AGENT_ATTORNEY_CITY', 'AGENT_ATTORNEY_STATE',
#        'JOB_TITLE', 'SOC_CODE', 'SOC_NAME', 'NAICS_CODE', 'TOTAL_WORKERS',
#        'NEW_EMPLOYMENT', 'CONTINUED_EMPLOYMENT', 'CHANGE_PREVIOUS_EMPLOYMENT',
#        'NEW_CONCURRENT_EMPLOYMENT', 'CHANGE_EMPLOYER', 'AMENDED_PETITION',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'PW_UNIT_OF_PAY',
#        'PW_WAGE_LEVEL', 'PW_SOURCE', 'PW_SOURCE_YEAR', 'PW_SOURCE_OTHER',
#        'WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_TO', 'WAGE_UNIT_OF_PAY',
# ...

# %%
df=df[df['EMPLOYER_COUNTRY']=='UNITED STATES OF AMERICA']

# %%
df.groupby('EMPLOYER_CITY').count()
# Out:
#                            CASE_NUMBER  CASE_STATUS  CASE_SUBMITTED  \
# EMPLOYER_CITY
# , KENOSHA                            1            1               1
# , ROCKVILLE CENTER                   5            5               5
# , WASHINGTON DC                      1            1               1
# 02116                                1            1               1
# 1                                    1            1               1
# 1020 EAST 1ST STREET                 1            1               1
# 1585 BROADWAY                        1            1               1
# 300                                  1            1               1
# 30071                                1            1               1
# 316 WEST UNIVERSITY DRIVE            1            1               1
# 500                                  1            1               1
# 601                                  1            1               1
# 7TH FLOOR                            1            1               1
# ...

# %%
new_df=df[['CASE_NUMBER','CASE_STATUS','CASE_SUBMITTED','DECISION_DATE','EMPLOYMENT_END_DATE','EMPLOYMENT_END_DATE','EMPLOYER_NAME','EMPLOYER_CITY','EMPLOYER_STATE','JOB_TITLE','NAICS_CODE','TOTAL_WORKERS','FULL_TIME_POSITION','PREVAILING_WAGE','WORKSITE_STATE']]

# %%
new_df=new_df[new_df['PREVAILING_WAGE']>0]

# %%
len(new_df)
# Out:
# 517324

# %%
new_df=new_df.dropna()

# %%
new_df.columns
# Out:
# Index(['CASE_NUMBER', 'CASE_STATUS', 'CASE_SUBMITTED', 'DECISION_DATE',
#        'EMPLOYMENT_END_DATE', 'EMPLOYMENT_END_DATE', 'EMPLOYER_NAME',
#        'EMPLOYER_CITY', 'EMPLOYER_STATE', 'JOB_TITLE', 'NAICS_CODE',
#        'TOTAL_WORKERS', 'FULL_TIME_POSITION', 'PREVAILING_WAGE',
#        'WORKSITE_STATE'],
#       dtype='object')

# %% [markdown]
# - Start with total H1B cases in 2017
# - Show the Case status numbers
# - Then see gegraphic distribution by states
# - see how lon does it usually take to decide a case
# - How often the positions are full time
# - Which companies are H1B dependent - more than 15% workforce H1B
# - Distribution of Prevailing wage by job type(NAICS CODE)
# - is worksite state usually same as employer state

# %%
new_df.to_csv('H1B.csv')
